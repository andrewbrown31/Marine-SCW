# %%
import wrf
import cartopy.crs as ccrs
import xarray as xr
import matplotlib.pyplot as plt
import netCDF4 as nc
import numpy as np
import metpy.calc as mpcalc
import metpy.units as units

# %%
def get_era5_thetae_grad(t):

    step=1
    LONG = np.array([145,165])
    LAT = np.array([-45,-25])
    lon_slice = slice(LONG.min(),LONG.max(),step)
    lat_slice = slice(LAT.max(),LAT.min(),step)

    # temp = xr.open_dataset("/g/data/rt52/era5/single-levels/reanalysis/2t/2023/2t_era5_oper_sfc_20231001-20231031.nc").t2m.sel(time=t,longitude=lon_slice,latitude=lat_slice)
    # dp = xr.open_dataset("/g/data/rt52/era5/single-levels/reanalysis/2d/2023/2d_era5_oper_sfc_20231001-20231031.nc").d2m.sel(time=t,longitude=lon_slice,latitude=lat_slice)
    # sp = xr.open_dataset("/g/data/rt52/era5/single-levels/reanalysis/sp/2023/sp_era5_oper_sfc_20231001-20231031.nc").sp.sel(time=t,longitude=lon_slice,latitude=lat_slice)
    temp = xr.open_dataset("/g/data/rt52/era5/pressure-levels/reanalysis/t/2023/t_era5_oper_pl_20231001-20231031.nc").t.sel(level=850,time=t,longitude=lon_slice,latitude=lat_slice)
    q = xr.open_dataset("/g/data/rt52/era5/pressure-levels/reanalysis/q/2023/q_era5_oper_pl_20231001-20231031.nc").q.sel(level=850,time=t,longitude=lon_slice,latitude=lat_slice)    
    msl = xr.open_dataset("/g/data/rt52/era5/single-levels/reanalysis/msl/2023/msl_era5_oper_sfc_20231001-20231031.nc").msl\
            .sel(time=t,longitude=slice(120,170),latitude=slice(-10,-60)).rolling({"latitude":6,"longitude":6}).mean().sel(longitude=lon_slice,latitude=lat_slice)

    ta_unit = units.units.K*temp
    dp_unit = mpcalc.dewpoint_from_specific_humidity(850 * units.units.hectopascals, ta_unit, q*units.units.dimensionless)
    thetae = np.array(mpcalc.equivalent_potential_temperature(850 * units.units.hectopascals, ta_unit, dp_unit))
    theta = np.array(mpcalc.potential_temperature(850 * units.units.hectopascals, ta_unit))    
    
    era5_lon = temp.longitude.values
    era5_lat = temp.latitude.values
    x, y = np.meshgrid(era5_lon,era5_lat)
    dx, dy = mpcalc.lat_lon_grid_deltas(x,y)

    ddy_thetae = mpcalc.first_derivative( thetae, delta=dy, axis=0)
    ddx_thetae = mpcalc.first_derivative( thetae, delta=dx, axis=1)
    mag_thetae = np.sqrt( ddx_thetae**2 + ddy_thetae**2)
    
    ddy_theta = mpcalc.first_derivative( theta, delta=dy, axis=0)
    ddx_theta = mpcalc.first_derivative( theta, delta=dx, axis=1)
    mag_theta = np.sqrt( ddx_theta**2 + ddy_theta**2)    
    
    return theta, thetae, mag_thetae, mag_theta, era5_lon, era5_lat, msl

def load_wrf(t,path):

    #Load WRF
    d="d01"
    step=6
    wrflist = nc.Dataset(path+"highres_"+d+"_"+t)
    theta = wrf.getvar(wrflist,"theta")
    
    U = wrf.getvar(wrflist,"U10").isel(west_east=slice(0,-1,step), south_north=slice(0,-1,step))
    V = wrf.getvar(wrflist,"V10").isel(west_east=slice(0,-1,step), south_north=slice(0,-1,step))
    LONG = wrf.getvar(wrflist,"XLONG").isel(west_east=slice(0,-1,step), south_north=slice(0,-1,step))
    LAT = wrf.getvar(wrflist,"XLAT").isel(west_east=slice(0,-1,step), south_north=slice(0,-1,step))
    
    return LONG,LAT,U,V,theta

def load_era5(t):
    #Load ERA5
    era5_u = xr.open_dataset("/g/data/rt52/era5/single-levels/reanalysis/10u/2023/10u_era5_oper_sfc_20231001-20231031.nc")
    era5_v = xr.open_dataset("/g/data/rt52/era5/single-levels/reanalysis/10v/2023/10v_era5_oper_sfc_20231001-20231031.nc")

    step=4
    LONG = np.array([145,165])
    LAT = np.array([-45,-25])
    lon_slice = slice(LONG.min(),LONG.max(),step)
    lat_slice = slice(LAT.max(),LAT.min(),step)
    era5_u_slice = era5_u.sel(time=t.split("_")[0] + " " + t.split("_")[1],longitude=lon_slice,latitude=lat_slice)
    era5_v_slice = era5_v.sel(time=t.split("_")[0] + " " + t.split("_")[1],longitude=lon_slice,latitude=lat_slice)

    theta, thetae, mag_thetae, mag_theta, era5_lon, era5_lat, msl = get_era5_thetae_grad(t.split("_")[0] + " " + t.split("_")[1])
    
    return era5_u_slice, era5_v_slice, theta, thetae, mag_thetae, mag_theta, era5_lon, era5_lat, msl

# %%
# Out:
# '2023-10-16 06:00:00 UTC'

# %%
plt.figure(figsize=[12,12])

cnt=1
for t in ["2023-10-15_21:00:00", "2023-10-16_00:00:00", "2023-10-16_03:00:00", "2023-10-16_06:00:00"]:

    #Plot ERA5
    ax=plt.subplot(2,2,cnt,projection=ccrs.PlateCarree())
    era5_u_slice, era5_v_slice, theta, thetae, mag_thetae, mag_theta, era5_lon, era5_lat, msl = load_era5(t)
    cf=ax.contourf(era5_lon,era5_lat,theta,cmap="Blues_r",levels=np.linspace(280,310,11),extend="both",alpha=0.8)
    c=ax.contour(era5_lon,era5_lat,(msl/100).values,colors=["grey"],levels=np.arange(1006,1022,2))
    text = plt.clabel(c,colors='k')
    [t.set_fontweight("bold") for t in text]
    x,y = np.meshgrid(era5_u_slice.longitude.values,era5_u_slice.latitude.values)
    ax.quiver(x,y,era5_u_slice.u10,era5_v_slice.v10,width=0.004,color="k",zorder=10)
    ax.coastlines()
    ax.gridlines(ls=":",draw_labels=["left","bottom"])
    ax.plot(154.3239, -35.9070, marker="x", color="k", ms=10, mew=2)
    plt.title(t.replace("_"," ")+" UTC")
    # plt.contourf(era5_lon, era5_lat, np.array(mag_thetae.to("1/km")*100) > 5, colors=["none","tab:blue"])

    cnt=cnt+1
    
cb=plt.colorbar(cf,plt.axes([0.2,0.05,0.6,0.02]),orientation="horizontal")
cb.set_label("Equivalent potential temperature (K)")

# %%
plt.figure(figsize=[16,16])

cnt=1
for t in ["2023-10-15_18:00:00", "2023-10-15_21:00:00", "2023-10-16_00:00:00", "2023-10-16_03:00:00"]:

    #Plot WRF
    path = "/g/data/w40/ab4502/WRF_simulations/tasman_d04_20231015_20231016_ramssa_shortlead/"
    LONG,LAT,U,V,theta = load_wrf(t,path)
    ax=plt.subplot(4,2,cnt,projection=ccrs.PlateCarree())
    theta.isel(bottom_top=0).plot(x="XLONG",y="XLAT",cmap="Blues",transform=ccrs.PlateCarree(),levels=np.linspace(280,310,11))
    step=6
    plt.gca().quiver(LONG,LAT,U,V,width=0.004)
    ax.coastlines()
    ax.gridlines(ls=":",draw_labels=["left","bottom"])

    cnt=cnt+1

    #Plot ERA5
    ax=plt.subplot(4,2,cnt,projection=ccrs.PlateCarree())
    era5_u_slice, era5_v_slice, theta, thetae, mag_thetae, era5_lon, era5_lat = load_era5(t)
    ax.contourf(era5_lon,era5_lat,theta,cmap="Blues",levels=np.linspace(280,310,11))
    x,y = np.meshgrid(era5_u_slice.longitude.values,era5_u_slice.latitude.values)
    ax.quiver(x,y,era5_u_slice.u10,era5_v_slice.v10,width=0.004)
    ax.coastlines()
    ax.gridlines(ls=":",draw_labels=["left","bottom"])

    cnt=cnt+1
# Out:
# 0.3.0

# %%
plt.figure(figsize=[16,16])

cnt=1
for t in ["2023-10-15_18:00:00", "2023-10-15_21:00:00", "2023-10-16_00:00:00", "2023-10-16_03:00:00"]:

    path = "/g/data/w40/ab4502/WRF_simulations/tasman_d04_20231015_20231016_ramssa_shortlead/"
    LONG,LAT,U,V,theta = load_wrf(t,path)
    ax=plt.subplot(4,2,cnt,projection=ccrs.PlateCarree())
    theta.isel(bottom_top=0).plot(x="XLONG",y="XLAT",cmap="Blues",transform=ccrs.PlateCarree(),levels=np.linspace(280,310,11))
    plt.gca().quiver(LONG,LAT,U,V,width=0.004)
    ax.coastlines()
    ax.gridlines(ls=":",draw_labels=["left","bottom"])

    cnt=cnt+1

    try:
        path = "/g/data/v46/ab4502/WRF_simulations/tasman_d04_20231015_20231016_ramssa_nov23_shortlead/"
        LONG,LAT,U,V,theta = load_wrf(t,path)
    except:
        path = "/g/data/w40/ab4502/WRF_simulations/tasman_d04_20231016_20231016_ramssa_nov23_shortlead/"
        LONG,LAT,U,V,theta = load_wrf(t,path)        
    ax=plt.subplot(4,2,cnt,projection=ccrs.PlateCarree())
    theta.isel(bottom_top=0).plot(x="XLONG",y="XLAT",cmap="Blues",transform=ccrs.PlateCarree(),levels=np.linspace(280,310,11))
    plt.gca().quiver(LONG,LAT,U,V,width=0.004)
    ax.coastlines()
    ax.gridlines(ls=":",draw_labels=["left","bottom"])

    cnt=cnt+1
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 18
#      17     path = "/g/data/v46/ab4502/WRF_simulations/tasman_d04_20231015_20231016_ramssa_nov23_shortlead/"
# ---> 18     LONG,LAT,U,V,theta = load_wrf(t,path)
#      19 except:
#
# Cell In[2], line 32, in load_wrf(t, path)
#      31 step=6
# ---> 32 wrflist = nc.Dataset(path+"highres_"+d+"_"+t)
#      33 theta = wrf.getvar(wrflist,"theta")
#
# File src/netCDF4/_netCDF4.pyx:2353, in netCDF4._netCDF4.Dataset.__init__()
#
# File src/netCDF4/_netCDF4.pyx:1963, in netCDF4._netCDF4._ensure_nc_success()
#
# FileNotFoundError: [Errno 2] No such file or directory: b'/g/data/v46/ab4502/WRF_simulations/tasman_d04_20231015_20231016_ramssa_nov23_shortlead/highres_d01_2023-10-15_18:00:00'
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
def get_era5_thetae_grad(t):

    step=1
    lon_slice = slice(120,LONG.max(),step)
    lat_slice = slice(-20,-50,step)

    temp = xr.open_dataset("/g/data/rt52/era5/single-levels/reanalysis/2t/2023/2t_era5_oper_sfc_20231001-20231031.nc").t2m.sel(time=t,longitude=lon_slice,latitude=lat_slice)
    dp = xr.open_dataset("/g/data/rt52/era5/single-levels/reanalysis/2d/2023/2d_era5_oper_sfc_20231001-20231031.nc").d2m.sel(time=t,longitude=lon_slice,latitude=lat_slice)
    sp = xr.open_dataset("/g/data/rt52/era5/single-levels/reanalysis/sp/2023/sp_era5_oper_sfc_20231001-20231031.nc").sp.sel(time=t,longitude=lon_slice,latitude=lat_slice)

    ta_unit = units.units.K*temp
    dp_unit = units.units.K*dp
    thetae = np.array(mpcalc.equivalent_potential_temperature(sp * units.units.pascal, ta_unit, dp_unit))
    theta = np.array(mpcalc.potential_temperature(sp * units.units.pascal, ta_unit))    
    
    era5_lon = temp.longitude.values
    era5_lat = temp.latitude.values
    x, y = np.meshgrid(era5_lon,era5_lat)
    dx, dy = mpcalc.lat_lon_grid_deltas(x,y)

    ddy_thetae = mpcalc.first_derivative( thetae, delta=dy, axis=0)
    ddx_thetae = mpcalc.first_derivative( thetae, delta=dx, axis=1)
    mag_thetae = np.sqrt( ddx_thetae**2 + ddy_thetae**2)
    
    return theta, thetae, mag_thetae, era5_lon, era5_lat

def load_era5(t):
    #Load ERA5
    era5_u = xr.open_dataset("/g/data/rt52/era5/single-levels/reanalysis/10u/2023/10u_era5_oper_sfc_20231001-20231031.nc")
    era5_v = xr.open_dataset("/g/data/rt52/era5/single-levels/reanalysis/10v/2023/10v_era5_oper_sfc_20231001-20231031.nc")

    step=5
    lon_slice = slice(120,LONG.max(),step)
    lat_slice = slice(-20,-50,step)
    era5_u_slice = era5_u.sel(time=t.split("_")[0] + " " + t.split("_")[1],longitude=lon_slice,latitude=lat_slice)
    era5_v_slice = era5_v.sel(time=t.split("_")[0] + " " + t.split("_")[1],longitude=lon_slice,latitude=lat_slice)

    theta, thetae, mag_thetae, era5_lon, era5_lat = get_era5_thetae_grad(t.split("_")[0] + " " + t.split("_")[1])
    
    return era5_u_slice, era5_v_slice, theta, thetae, mag_thetae, era5_lon, era5_lat


plt.figure(figsize=[16,8])

cnt=1
for t in ["2023-10-15_18:00:00", "2023-10-15_21:00:00", "2023-10-16_00:00:00", "2023-10-16_03:00:00"]:

    #Plot ERA5
    ax=plt.subplot(2,2,cnt,projection=ccrs.PlateCarree())
    era5_u_slice, era5_v_slice, theta, thetae, mag_thetae, era5_lon, era5_lat = load_era5(t)
    c=ax.contourf(era5_lon,era5_lat,theta,cmap="Blues_r",levels=np.linspace(270,300,11))
    x,y = np.meshgrid(era5_u_slice.longitude.values,era5_u_slice.latitude.values)
    ax.quiver(x,y,era5_u_slice.u10,era5_v_slice.v10,width=0.004)
    ax.coastlines()
    ax.gridlines(ls=":",draw_labels=["left","bottom"])
    
    plt.title(t)
    
    plt.colorbar(c)

    cnt=cnt+1

# %%
era5_lat
# Out:
# array([-29.75, -30.  , -30.25, -30.5 , -30.75, -31.  , -31.25, -31.5 ,
#        -31.75, -32.  , -32.25, -32.5 , -32.75, -33.  , -33.25, -33.5 ,
#        -33.75, -34.  , -34.25, -34.5 , -34.75, -35.  , -35.25, -35.5 ,
#        -35.75, -36.  , -36.25, -36.5 , -36.75, -37.  , -37.25, -37.5 ,
#        -37.75, -38.  , -38.25, -38.5 , -38.75, -39.  , -39.25, -39.5 ,
#        -39.75, -40.  , -40.25, -40.5 , -40.75, -41.  , -41.25, -41.5 ,
#        -41.75, -42.  , -42.25, -42.5 , -42.75, -43.  , -43.25, -43.5 ,
#        -43.75, -44.  , -44.25, -44.5 , -44.75, -45.  , -45.25, -45.5 ,
#        -45.75, -46.  , -46.25, -46.5 , -46.75, -47.  , -47.25, -47.5 ,
#        -47.75, -48.  , -48.25, -48.5 , -48.75, -49.  , -49.25, -49.5 ,
#        -49.75, -50.  ], dtype=float32)
