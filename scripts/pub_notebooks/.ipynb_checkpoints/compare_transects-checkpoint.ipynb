# %%
import xarray as xr
import numpy as np
import cartopy.crs as ccrs
import matplotlib.pyplot as plt
import wrf
import netCDF4 as nc
import warnings
import pyart
import pandas as pd
import tqdm
import metpy.calc as mpcalc

warnings.simplefilter("ignore")
# Out:
# ## You are using the Python ARM Radar Toolkit (Py-ART), an open source
# ## library for working with weather radar data. Py-ART is partly
# ## supported by the U.S. Department of Energy as part of the Atmospheric
# ## Radiation Measurement (ARM) Climate Research Facility, an Office of
# ## Science user facility.
# ##
# ## If you use this software to prepare a publication, please cite:
# ##
# ##     JJ Helmus and SM Collis, JORS 2016, doi: 10.5334/jors.119
# <frozen importlib._bootstrap>:283: DeprecationWarning: the load_module() method is deprecated and slated for removal in Python 3.12; use exec_module() instead
# 0.3.0

# %%
def load_transect(tpath,t_fname,hpath,h_fname):

    #Load cross section
    ctrl = xr.open_dataset(tpath + t_fname)
    
    #Change theta pert. Define as the perturbation in theta relative to the transect at each height.
    ctrl["theta_pert"] = ctrl["theta"] - ctrl.theta.sel(cross_line_idx=slice(25,50)).mean(("cross_line_idx","transect"))
    
    #Define cold pool depth, H, as when the mean cold pool theta perturbation goes above -1 K
    thresh=-1
    cond = (ctrl.sel(cross_line_idx=slice(0,25),vertical=slice(0,3000)).theta_pert).mean("cross_line_idx") <= thresh
    heights = np.repeat(ctrl.sel(vertical=slice(0,3000)).vertical.values[np.newaxis],cond.transect.shape[0],axis=0)
    H = np.nanmax(np.where(cond,heights,np.nan),axis=1)
    ctrl["H"] = (["transect"],H)
    
    #Ambient wind, U0, defined as the mean line-perpendicular wind speed ahead of the cold pool over H
    U0 = [ctrl["along_transect_wind"].sel(cross_line_idx=slice(25,50),vertical=slice(0,h),transect=t).mean(("cross_line_idx","vertical"))\
          for t, h in zip(range(ctrl.transect.shape[0]), H)]
    ctrl["U0"] = (["transect"],U0)    
    
    #Cold pool speed, Uc, defined as the maximum surace wind speed in the cold pool
    #Uc = [ctrl["along_transect_wind"].sel(cross_line_idx=slice(20,25),vertical=slice(0,h),transect=t).mean(("cross_line_idx","vertical"))\
    #     for h, t in zip(H, range(ctrl.transect.shape[0]))]
    #ctrl["Uc"] = (["transect"],Uc)    
    ctrl["Uc"] = ctrl["along_transect_wind"].sel(cross_line_idx=slice(0,25)).isel(vertical=0).max(("cross_line_idx"))
    
    return ctrl.assign_coords({"transect":ctrl.transect})

    
def latlon_dist(lat, lon, lats, lons):

        #Calculate great circle distance (Harversine) between a lat lon point (lat, lon) and a list of lat lon
        # points (lats, lons)

        R = 6373.0

        lat1 = np.deg2rad(lat)
        lon1 = np.deg2rad(lon)
        lat2 = np.deg2rad(lats)
        lon2 = np.deg2rad(lons)

        dlon = lon2 - lon1
        dlat = lat2 - lat1

        a = np.sin(dlat / 2)**2 + np.cos(lat1) * np.cos(lat2) * np.sin(dlon / 2)**2
        c = 2 * np.arctan2(np.sqrt(a), np.sqrt(1 - a))

        return (R * c)

# %%
tpath = "/g/data/w40/ab4502/WRF_simulations/transects/"
hpath = "/g/data/w40/ab4502/WRF_simulations/tasman_d04_20231015_20231016_ramssa_shortlead/"

t_fname = ["tasman_d04_20231015_20231016_ramssa_shortlead_02:30:00.nc",
           "tasman_d04_20231015_20231016_ramssa_shortlead_03:00:00.nc",
           "tasman_d04_20231015_20231016_ramssa_shortlead_03:30:00.nc"]
h_fname = ["highres_d04_2023-10-16_02:30:00",
           "highres_d04_2023-10-16_03:00:00",
           "highres_d04_2023-10-16_03:30:00"]
ctrl_list = []

for t, h in tqdm.tqdm(zip(t_fname,h_fname)):
    ctrl = load_transect(tpath,t,hpath,h)
    ctrl_list.append(ctrl)
    
for i in range(1,len(ctrl_list)):
    ctrl_list[i] = ctrl_list[i].interp({"cross_line_idx":ctrl_list[0].cross_line_idx},method="linear")
    
ctrl_list = xr.concat(ctrl_list,"Time")
# Out:
# 3it [00:00, 16.91it/s]

# %%
tpath = "/g/data/w40/ab4502/WRF_simulations/transects/"
hpath = "/g/data/w40/ab4502/WRF_simulations/tasman_d04_20231015_20231016_ramssa_shortlead_3Kplus/"

t_fname = ["tasman_d04_20231015_20231016_ramssa_shortlead_3Kplus_02:30:00.nc",
           "tasman_d04_20231015_20231016_ramssa_shortlead_3Kplus_03:00:00.nc",
           "tasman_d04_20231015_20231016_ramssa_shortlead_3Kplus_03:30:00.nc"]
h_fname = ["highres_d04_2023-10-16_02:30:00",
           "highres_d04_2023-10-16_03:00:00",
           "highres_d04_2023-10-16_03:30:00"]
plus_3K_list = []

for t, h in tqdm.tqdm(zip(t_fname,h_fname)):
    plus_3K = load_transect(tpath,t,hpath,h)
    plus_3K_list.append(plus_3K)
    
for i in range(1,len(plus_3K_list)):
    plus_3K_list[i] = plus_3K_list[i].interp({"cross_line_idx":plus_3K_list[0].cross_line_idx},method="linear")
    
plus_3K_list = xr.concat(plus_3K_list,"Time")
# Out:
# 3it [00:00, 16.97it/s]

# %%
tpath = "/g/data/w40/ab4502/WRF_simulations/transects/"
hpath = "/g/data/w40/ab4502/WRF_simulations/tasman_d04_20231015_20231016_ramssa_shortlead_3Kminus/"

t_fname = ["tasman_d04_20231015_20231016_ramssa_shortlead_3Kminus_02:30:00.nc",
           "tasman_d04_20231015_20231016_ramssa_shortlead_3Kminus_03:00:00.nc",
           "tasman_d04_20231015_20231016_ramssa_shortlead_3Kminus_03:30:00.nc"]
h_fname = ["highres_d04_2023-10-16_02:30:00",
           "highres_d04_2023-10-16_03:00:00",
           "highres_d04_2023-10-16_03:30:00"]
minus_3K_list = []

for t, h in tqdm.tqdm(zip(t_fname,h_fname)):
    minus_3K = load_transect(tpath,t,hpath,h)
    minus_3K_list.append(minus_3K)
    
for i in range(1,len(minus_3K_list)):
    minus_3K_list[i] = minus_3K_list[i].interp({"cross_line_idx":minus_3K_list[0].cross_line_idx},method="linear")    
    
minus_3K_list = xr.concat(minus_3K_list,"Time")
# Out:
# 3it [00:00, 17.25it/s]

# %%
def theory(ls):
    theta1 = ls.rho.sel(cross_line_idx=slice(20,25)).isel(vertical=0).mean(("cross_line_idx"))
    theta2 = ls.rho.sel(cross_line_idx=slice(25,30)).isel(vertical=0).mean(("cross_line_idx"))

    k = 1
    b = 0.74
    g = 9.8

    density_speed = ((k * np.sqrt(g * ls.H * (theta1-theta2)/theta1)))
    ambient_speed =  b*ls["U0"]
    total_speed = density_speed + ambient_speed
    
    print("H=",ls.H.mean(("transect","Time")).values.round(2),
          "\nRho diff=",((theta1-theta2)).mean(("transect","Time")).values.round(3),
         "\nRho 1=",(theta1).mean(("transect","Time")).values.round(3),
         "\nRho 2=",(theta2).mean(("transect","Time")).values.round(3),)
    
    return total_speed, density_speed, ambient_speed

def find_speed(ctrl_list):
    
    system_lats = []
    system_lons = []
    speed = []
    for i, j in zip([0,1],[1,2]):
            for t in range(30):
                system_lat1 = ctrl_list.isel(Time=i).sel(transect=t,cross_line_idx=25,method="nearest").xy_lat.values
                system_lon1 = ctrl_list.isel(Time=i).sel(transect=t,cross_line_idx=25,method="nearest").xy_lon.values
                system_lat2 = ctrl_list.isel(Time=j).sel(transect=t,cross_line_idx=25,method="nearest").xy_lat.values
                system_lon2 = ctrl_list.isel(Time=j).sel(transect=t,cross_line_idx=25,method="nearest").xy_lon.values    
                delta_t = (ctrl_list.isel(Time=j).Time - ctrl_list.isel(Time=i).Time).values / np.timedelta64(1, 'h')
                speed.append((latlon_dist(system_lat1,system_lon1,system_lat2,system_lon2)/delta_t/3.6))

    return np.median(speed)

# %%
ls = ctrl_list
uc = []
ut = []
ut_density = []
ut_ambient = []
index = ["All transects","Transects 1-15","Transects 16-30"]
for transect_slice in [slice(0,30),slice(0,14),slice(15,30)]:
    uc.append(ls.sel(transect=transect_slice).Uc.mean())
    total_speed, density_speed, ambient_speed = theory(ls.sel(transect=transect_slice))
    ut.append(total_speed.mean().values)
    ut_density.append(density_speed.mean().values)
    ut_ambient.append(ambient_speed.mean().values) 

pd.DataFrame({"$U_c$ (m/s)":uc,"$U_t$ (m/s)":ut,"$U_t$ (density, m/s)":ut_density,"$U_t$ (ambient wind, m/s)":ut_ambient},
            index=index).astype(float).round(decimals=1)
# Out:
# H= 1057.23
# Rho diff= 0.012
# Rho 1= 1.211
# Rho 2= 1.2
# H= 1141.73
# Rho diff= 0.013
# Rho 1= 1.213
# Rho 2= 1.2
# H= 972.74
# Rho diff= 0.01
# Rho 1= 1.21
# Rho 2= 1.2
#                  $U_c$ (m/s)  $U_t$ (m/s)  $U_t$ (density, m/s)  \
# All transects           16.3         16.5                   9.9
# Transects 1-15          18.1         18.2                  10.8
# Transects 16-30         14.6         14.9                   9.0
#
#                  $U_t$ (ambient wind, m/s)
# All transects                          6.6
# Transects 1-15                         7.4
# Transects 16-30                        5.9

# %%
ls = ctrl_list
uc = []
ut = []
ut_density = []
ut_ambient = []
index = ["WRF CTRL","WRF +3K","WRF -3K"]
transect_slice = slice(0,30)
for ls in [ctrl_list,plus_3K_list,minus_3K_list]:
    #uc.append(find_speed(ls))
    uc.append(ls.sel(transect=transect_slice).Uc.mean())
    total_speed, density_speed, ambient_speed = theory(ls.sel(transect=transect_slice))
    ut.append(total_speed.mean().values)
    ut_density.append(density_speed.mean().values)
    ut_ambient.append(ambient_speed.mean().values) 

pd.DataFrame({"$U_c$ (m/s)":uc,"$U_t$ (m/s)":ut,"$U_t$ (density, m/s)":ut_density,"$U_t$ (ambient wind, m/s)":ut_ambient},
            index=index).astype(float).round(decimals=1)
# Out:
# H= 1057.23
# Rho diff= 0.012
# Rho 1= 1.211
# Rho 2= 1.2
# H= 1109.54
# Rho diff= 0.009
# Rho 1= 1.203
# Rho 2= 1.195
# H= 1008.95
# Rho diff= 0.008
# Rho 1= 1.217
# Rho 2= 1.209
#           $U_c$ (m/s)  $U_t$ (m/s)  $U_t$ (density, m/s)  \
# WRF CTRL         16.3         16.5                   9.9
# WRF +3K          16.5         16.7                   8.8
# WRF -3K          12.2         14.7                   8.1
#
#           $U_t$ (ambient wind, m/s)
# WRF CTRL                        6.6
# WRF +3K                         7.9
# WRF -3K                         6.6

# %%
ls = ctrl_list
uc = []
ut = []
ut_density = []
ut_ambient = []
index = ["WRF CTRL","WRF +3K","WRF -3K"]
transect_slice = slice(0,14)
for ls in [ctrl_list,plus_3K_list,minus_3K_list]:
    #uc.append(find_speed(ls))
    uc.append(ls.sel(transect=transect_slice).Uc.mean())
    total_speed, density_speed, ambient_speed = theory(ls.sel(transect=transect_slice))
    ut.append(total_speed.mean().values)
    ut_density.append(density_speed.mean().values)
    ut_ambient.append(ambient_speed.mean().values) 

pd.DataFrame({"$U_c$ (m/s)":uc,"$U_t$ (m/s)":ut,"$U_t$ (density, m/s)":ut_density,"$U_t$ (ambient wind, m/s)":ut_ambient},
            index=index).astype(float).round(decimals=1)
# Out:
# H= 1141.73
# Rho diff= 0.013
# Rho 1= 1.213
# Rho 2= 1.2
# H= 1029.07
# Rho diff= 0.008
# Rho 1= 1.202
# Rho 2= 1.194
# H= 1061.26
# Rho diff= 0.008
# Rho 1= 1.218
# Rho 2= 1.21
#           $U_c$ (m/s)  $U_t$ (m/s)  $U_t$ (density, m/s)  \
# WRF CTRL         18.1         18.2                  10.8
# WRF +3K          18.9         18.4                   8.3
# WRF -3K          13.3         15.1                   8.3
#
#           $U_t$ (ambient wind, m/s)
# WRF CTRL                        7.4
# WRF +3K                        10.0
# WRF -3K                         6.8

# %%
plt.figure(figsize=[16,5])
plt.subplot(1,3,1)

transect_slice=slice(0,14)
ctrl_list.sel(transect=transect_slice,cross_line_idx=slice(25,50),vertical=slice(0,3000)).along_transect_wind.mean(("transect","cross_line_idx","Time")).plot(y="vertical")
plus_3K_list.sel(transect=transect_slice,cross_line_idx=slice(25,50),vertical=slice(0,3000)).along_transect_wind.mean(("transect","cross_line_idx","Time")).plot(y="vertical",color="tab:red")
minus_3K_list.sel(transect=transect_slice,cross_line_idx=slice(25,50),vertical=slice(0,3000)).along_transect_wind.mean(("transect","cross_line_idx","Time")).plot(y="vertical",color="tab:purple")
plt.gca().grid(ls=":")
plt.ylabel("Height (m)")
plt.title("Line-perpendicular ambient wind speed")
plt.xlabel("m/s")

plt.subplot(1,3,2)
(ctrl_list.rho.sel(transect=transect_slice,cross_line_idx=slice(20,25),vertical=slice(0,3000)).mean(("cross_line_idx","transect")) -\
     ctrl_list.rho.sel(transect=transect_slice,cross_line_idx=slice(25,30),vertical=slice(0,3000)).mean(("cross_line_idx","transect"))).mean(("Time")).plot(y="vertical",label="CTRL")
(plus_3K_list.rho.sel(transect=transect_slice,cross_line_idx=slice(20,25),vertical=slice(0,3000)).mean(("cross_line_idx","transect")) -\
     plus_3K_list.rho.sel(transect=transect_slice,cross_line_idx=slice(25,30),vertical=slice(0,3000)).mean(("cross_line_idx","transect"))).mean(("Time")).plot(y="vertical",label="+3K SST",color="tab:red")

(minus_3K_list.rho.sel(transect=transect_slice,cross_line_idx=slice(20,25),vertical=slice(0,3000)).mean(("cross_line_idx","transect")) -\
     minus_3K_list.rho.sel(transect=transect_slice,cross_line_idx=slice(25,30),vertical=slice(0,3000)).mean(("cross_line_idx","transect"))).mean(("Time")).plot(y="vertical",label="-3K SST",color="tab:purple")
plt.legend()
plt.ylabel("")
plt.gca().grid(ls=":")
plt.title("Density difference")
plt.xlabel("kg/m$^{3}$")

plt.subplot(1,3,3)
ctrl_list.sel(transect=transect_slice,vertical=slice(0,3000)).w.max("cross_line_idx").mean(("transect","Time")).plot(y="vertical")
plus_3K_list.sel(transect=transect_slice,vertical=slice(0,3000)).w.max("cross_line_idx").mean(("transect","Time")).plot(y="vertical",color="tab:red")
minus_3K_list.sel(transect=transect_slice,vertical=slice(0,3000)).w.max("cross_line_idx").mean(("transect","Time")).plot(y="vertical",color="tab:purple")
plt.gca().grid(ls=":")
plt.ylabel("")
plt.title("Mean maximum updraft along transect")
plt.xlabel("m/s")
# Out:
# Text(0.5, 0, 'm/s')

# %%
def theory_transect(ls):
    theta1 = ls.rho.sel(cross_line_idx=slice(20,25)).isel(vertical=0).mean(("cross_line_idx"))
    theta2 = ls.rho.sel(cross_line_idx=slice(25,30)).isel(vertical=0).mean(("cross_line_idx"))

    k = 1
    b = 0.74
    g = 9.8

    density_speed = ((k * np.sqrt(g * ls.H * (theta1-theta2)/theta1)))
    ambient_speed =  b*ls["U0"]
    total_speed = density_speed + ambient_speed
    
    return total_speed, density_speed, ambient_speed

plt.figure(figsize=[16,4])
for t in [0,1,2]:
    plt.subplot(1,3,t+1)
    theory_transect(ctrl_list)[0].isel(Time=t).plot(color="tab:blue",ls="-")
    theory_transect(ctrl_list)[1].isel(Time=t).plot(color="tab:blue",ls=":")
    theory_transect(ctrl_list)[2].isel(Time=t).plot(color="tab:blue",ls="--")
    ctrl_list.ground_rel_ws.isel(Time=t,vertical=0).max("cross_line_idx").plot(color="k")
    plt.ylim([0,23])
    plt.gca().grid(ls=":")
    
plt.figure(figsize=[16,4])
for t,ls,c,title in zip([0,1,2],[ctrl_list,plus_3K_list,minus_3K_list],["tab:blue","tab:red","tab:purple"],["WRF CTRL","WRF +3K","WRF -3K"]):
    plt.subplot(1,3,t+1)
    plt.plot(range(1,31),theory_transect(ls)[0].mean("Time"),color=c,ls="-")
    plt.plot(range(1,31),theory_transect(ls)[1].mean("Time"),color=c,ls=":")
    plt.plot(range(1,31),theory_transect(ls)[2].mean("Time"),color=c,ls="--")
    plt.plot(range(1,31),ls.Uc.mean("Time"),color="k",ls=":")
    plt.ylim([0,23])
    plt.gca().grid(ls=":") 
    plt.title(title)
    
plt.figure(figsize=[5.333,4])
c="tab:blue"
plt.plot(range(1,31),theory_transect(ctrl_list)[0].mean("Time"),color=c,ls="-")
plt.plot(range(1,31),theory_transect(ctrl_list)[1].mean("Time"),color=c,ls=":")
plt.plot(range(1,31),theory_transect(ctrl_list)[2].mean("Time"),color=c,ls="--")
plt.plot(range(1,31),ctrl_list.Uc.mean("Time"),color="k")
plt.ylim([0,23])
plt.gca().grid(ls=":") 
plt.title("")
# Out:
# Text(0.5, 1.0, '')
